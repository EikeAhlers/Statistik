# %% [markdown]
# <h1>Übung 7

# %%
library("readxl")

# %% [markdown]
# Lese die Excel Datei:

# %%
data <- read_excel("S_Land_Excel.xlsx")

# %% [markdown]
# Zeige die Excel Datei:

# %%
data
# Out:
#     Familie Erntesteigerung Erwartung Werbung Technologie Produkt Motivation
# 1    1       5              2         29       3          0       3
# 2    2       8              1         30       5          1       2
# 3    3      18              3         16       6          0       2
# 4    4      10              2         22       5          1       1
# 5    5       7              1          9       9          1       2
# 6    6      12              2         14       8          1       3
# 7    7      16              2         26       0          1       2
# 8    8       2              1         26       4          1       1
# 9    9       4              1         28       8          1       2
# 10  10      10              1         31       0          1       3
# 11  11       7              1          6       3          1       2
# 12  12       9              1         30       0          1       2
# 13  13       4              1         22       0          1       2
# ...
